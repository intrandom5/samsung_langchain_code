# %% [markdown]
# 앞서 배운 내용을 바탕으로 간단한 대화 가능한 챗봇을 만들어 봅시다!
#
# 앞서 살펴본 `llm_api.ipynb`의 코드를 적극적으로 참고하여 (혹은 복붙하며) 작성해 봅시다!

# %% [markdown]
# 1. 필요한 라이브러리 불러오기

# %% [markdown]
# 2. api key 불러오고, 모델 설정하기

# %% [markdown]
# 3. 모델 설정하기
#
# 설정 값들을 다양하게 바꿔 가면서 결과를 확인해 봅시다!
#
# (아래 코드의 빈 곳을 완성해 봅시다!)

# %%
# 모델 설정
model = init_chat_model(
    model=,
    api_key=,
    temperature=,
    max_tokens=,
)

# %% [markdown]
# 모델과 대화할 수 있는 함수 완성하기.
#
# (아래 코드의 빈 곳을 완성해 봅시다!)

# %%
# 우선 시스템 프롬프트를 먼저 추가해 볼까요?
messages = [
    
]

# 이 함수는 사용자의 메시지(message)를 입력 받으면, 그 메시지를 모델에 전달하고 답변을 기록하는 역할을 수행합니다.
def send_messages(message):
    # 모델에 보내기 전에, messages에 어떤 값이 추가되어야 할까요?
    messages.append(
        
    )

    # 모델로부터 결과를 받아 보려면 어떻게 해야 할까요?
    result = ?

    print(result)

    # 마지막으로 모델의 답변 결과를 messages에 추가하려면 어떻게 해야 할까요?
    messages.append(
        
    )

# %% [markdown]
# 위에서 구현한 함수를 이용해 마음껏 대화해 봅시다! (`message`의 내용을 바꾸면서 계속 실행하면 되겠죠?)

# %%
message = "안녕 반가워! 이제부터 네 이름은 두식이야."

send_messages(message)
# Out:
# 응, 나는 실제 몸이나 머리가 없는 AI야. 그래서 머리카락도 없고 두피도 없어.
# 그래도 대화는 잘할 수 있어 😄
